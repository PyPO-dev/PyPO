# %% [markdown]
# # Vectorial Gaussian Beams
#
# Per Cullen & Yu "Complex Source Point Theory of the Electromagnetic Open Resonator" (1979), we use the complex source point representation of a Gaussian beam to generate the E- and H- fields of a Gaussian beam.
#
# The complex source point method generates a Gaussian beam travelling along the positive z-axis by displacing a combined electric and magnetic dipole (oriented along the x- and y-axes respectively) by an imaginary distance $i z_c$ in the positive z direction.
#
# $z_c$ is the confocal distance of the beam, related to the wavelength $\lambda$ and the beamwaist radius $w_0$ by:
#
# $$ z_c = \frac{\pi w_0^2}{\lambda}$$

# %% [markdown]
# ## Symmetrization
#
# The magnetic dipole oriented along the y-axis is introduced in order to provide symmetry between the E- and H-fields, so that the fields satisfy the duality principle, and are invariant under the substitions
#
# $$ \mathbf{E} \rightarrow -Z \mathbf{H} $$
#
# $$ \mathbf{H} \rightarrow \frac{1}{Z} \mathbf{E} $$
#
# $$ \mathbf{J} \rightarrow -\frac{1}{Z} \mathbf{M} $$
#
# $$ \mathbf{M} \rightarrow Z \mathbf{J} $$
#
#
# The strength $p_m$ of the magnetic dipole required to symmetrize an electric dipole of strengh $p_e$ is given by
#
# $$ p_m = - p_e \sqrt{\epsilon / \mu} = - p_e / Z $$
#
# where $Z$ is the impedance of freespace.

# %% [markdown]
# # Cullen & Yu Gaussian Beam
#
# Assuming a time factor of $e^{i \omega t}$, according to Cullen & Yu, the fields due to the electric and magnetic dipoles at the origin are:
#
# $$ E_x = \frac{k^2}{r} e^{-ikr}\Bigg[\bigg(1 - \frac{i}{kr} - \frac{1}{(kr)^2}\bigg) - \bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{x^2}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = - \frac{k^2}{r} e^{-ikr}\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = - \frac{k^2}{r} e^{-ikr}\Bigg[\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{x(z + i z_c)}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = - \frac{k^2}{Z r} e^{-ikr}\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = \frac{k^2}{Z r} e^{-ikr}\Bigg[\bigg(1 - \frac{i}{kr} - \frac{1}{(kr)^2}\bigg) - \bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{y^2}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = - \frac{k^2}{Zr} e^{-ikr}\Bigg[\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{y(z + i z_c)}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# ## Normalization
#
# Cullen & Yu normalize these fields by multiplying by a factor
#
# $$ -i \frac{z_c}{ 2 k^2} e^{-k z_c} $$
#
# which gives a field strength of unity at $(0, 0, 0)$ for $E_x$.
#
# yielding:

# %% [markdown]
# $$ E_x = - i \frac{z_c}{2 r} e^{-k z_c} e^{-ikr} \Bigg[\bigg(1 - \frac{i}{kr} - \frac{1}{(kr)^2}\bigg) - \bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{x^2}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = - (-i) \frac{z_c}{2 r} e^{-k z_c}  e^{-ikr}\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = - (-i) \frac{z_c}{2 r} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{x(z + i z_c)}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = i \frac{z_c}{2 Z r} e^{-k z_c}  e^{-ikr}\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = - i \frac{z_c}{2 Z r} e^{-k z_c} e^{-ikr}\Bigg[\bigg(1 - \frac{i}{kr} - \frac{1}{(kr)^2}\bigg) - \bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{y^2}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = i \frac{z_c}{2 Z r} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(1 - \frac{3i}{kr} - \frac{3}{(kr)^2}\bigg)\frac{y(z + i z_c)}{r^2} + \bigg(1 - \frac{i}{kr}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# Multiplying the inverse kr power sums by $-i/kr$ gives

# %% [markdown]
# $$ E_x = \frac{z_c k}{2} e^{-k z_c} e^{-ikr} \Bigg[\bigg(\frac{-i}{kr} - \frac{1}{(kr)^2} +  \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{x^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = - \frac{z_c k}{2} e^{-k z_c}  e^{-ikr}\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = - \frac{z_c k}{2} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = - \frac{z_c k}{2 Z} e^{-k z_c}  e^{-ikr}\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = \frac{z_c k}{2 Z} e^{-k z_c} \frac{k^2}{Z r} e^{-ikr}\Bigg[\bigg(\frac{-i}{kr} - \frac{1}{(kr)^2} +  \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{y^2}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = -\frac{z_c k }{2 Z} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{y(z + i z_c)}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# We now substitute
#
# $$ z_c = \frac{\pi w_0^2}{\lambda} = \frac{k w_0^2}{2} $$

# %% [markdown]
# $$ E_x = \frac{k^2 w_0^2}{4} e^{-k z_c} e^{-ikr} \Bigg[\bigg(\frac{-i}{kr} - \frac{1}{(kr)^2} +  \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{x^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = - \frac{k^2 w_0^2}{4} e^{-k z_c}  e^{-ikr}\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = - \frac{k^2 w_0^2}{4} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = - \frac{k^2 w_0^2}{4 Z} e^{-k z_c}  e^{-ikr}\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = \frac{k^2 w_0^2}{4 Z} e^{-k z_c} e^{-ikr}\Bigg[\bigg(\frac{-i}{kr} - \frac{1}{(kr)^2} +  \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{y^2}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = - \frac{k^2 w_0^2}{4 Z} e^{-k z_c}  e^{-ikr}\Bigg[\bigg(\frac{i}{kr} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^3}\bigg)\frac{y(z + i z_c)}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# # Derivation in PyPO field convention
#
# Taking our fields for the source current dipole, we move the source by a complex distance $i z_c$.
#
# $$ \mathbf{E} = \frac{k^2}{4\pi} \Bigg\{ Z \Bigg[J \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + (\mathbf{J}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}}\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)\Bigg] $$
#
# $$ - \mathrm{M}\times\mathrm{\hat{R}}\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg)\Bigg\} e^{-ikR} $$
#
#
# $$ \mathbf{H} = \frac{k^2}{4\pi} \Bigg\{ \frac{1}{Z} \Bigg[M \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + (\mathbf{M}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}}\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)\Bigg] $$
#
# $$ + \mathrm{J}\times\mathrm{\hat{R}}\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg)\Bigg\} e^{-ikR} $$

# %% [markdown]
# We now explicilty calculate the $\mathbf{J}$, $\mathbf{M}$, $(\mathbf{J}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}}$, $(\mathbf{M}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}}$, $\mathbf{M}\times\mathbf{\hat{R}}$, and $\mathbf{J}\times\mathbf{\hat{R}}$ terms for a dipole of magnitude $J_x$ at a complex source point:
#
# $$\mathbf{R} = x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}} $$

# %% [markdown]
# $$|\mathbf{R}| = R = \sqrt{x^2 + y^2 + (z + i z_c )^2} = (z + i z_c) \sqrt{1 + \frac{x^2 + y^2}{(z + i z_c )^2}} $$

# %% [markdown]
# $$ \mathbf{\hat{R}} = \frac{\mathbf{R}} {|\mathbf{R}|} = \frac{x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}}{R} $$

# %% [markdown]
# $\mathbf{J}$ is orientated along the x-axis with magnitude $J_x$.  Thus
#
# $$ \mathbf{J} = J_x \mathbf{\hat{x}} $$
#
# $$ \mathbf{J} \cdot\mathbf{\hat{R}} = \frac{J_x x}{R} $$

# %% [markdown]
# $$ (\mathbf{J}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}} = \frac{J_x x}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)

# %% [markdown]
# and
#
# $$ \mathbf{J} \times \mathbf{\hat{R}} = J_x\mathbf{\hat{x}} \times \frac{x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}}{R} $$

# %% [markdown]
# $$ \mathbf{J} \times \mathbf{\hat{R}} = - J_x\Bigg(\frac{z + i z_c}{R} \mathbf{\hat{y}} - \frac{y}{R} \mathbf{\hat{z}} \Bigg) = -\frac{J_x (z + i z_c)}{R} \mathbf{\hat{y}} + \frac{J_x y}{R} \mathbf{\hat{z}}$$

# %% [markdown]
# Thus the fields due to an electric current element at a complex source point, aligned with the x-axis are:
#
# $$ \mathbf{E} = \frac{k^2}{4\pi} Z \Bigg[J_x \mathrm{\hat{x}} \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + \frac{J_x x}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)\Bigg] $$
#
# $$ \mathbf{H} = \frac{k^2}{4\pi} J_x\Bigg(\frac{y}{R} \mathbf{\hat{z}} - \frac{z + i z_c}{R} \mathbf{\hat{y}} \Bigg)\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg) e^{-ikR} $$

# %% [markdown]
# Similarly to the calculations for $\mathbf{J}$ above, for a magnetic current element $\mathbf{M}$ orientated along the y-axis:
#
# $$ (\mathbf{M}\cdot\mathbf{\hat{R}})\mathbf{\hat{R}} = \frac{M_y y}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)

# %% [markdown]
# and
#
# $$ \mathbf{M} \times \mathbf{\hat{R}} = M_y \Bigg(  \frac{z + i z_c}{R} \mathbf{\hat{x}} - \frac{x}{R} \mathbf{\hat{z}}\Bigg) $$

# %% [markdown]
# Thus the fields due to an Magnetic current element at a complex source point, aligned with the x-axis are:
#
# $$ \mathbf{E} = - \frac{k^2}{4\pi} M_y\Bigg(\frac{z + i z_c}{R} \mathbf{\hat{x}} - \frac{x}{R} \mathbf{\hat{z}} \Bigg)\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg) e^{-ikR} $$
#
# $$ \mathbf{H} = \frac{k^2}{4\pi} \frac{1}{Z} \Bigg[M_y \mathrm{\hat{y}} \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + \frac{M_y y}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)\Bigg] $$

# %% [markdown]
# # Symmetrization
#
# Our fields should obey the duality principle, where the fields are invariant under the substitution
#
# $$ \mathbf{E} \rightarrow -Z \mathbf{H} $$
#
# $$ \mathbf{H} \rightarrow \frac{1}{Z} \mathbf{E} $$
#
# $$ \mathbf{J} \rightarrow -\frac{1}{Z} \mathbf{M} $$
#
# $$ \mathbf{M} \rightarrow Z \mathbf{J} $$

# %% [markdown]
# We make the substitutions in the first set of equations:
#
# $$ \mathbf{H} = - \frac{k^2}{4\pi} \Bigg[-\frac{1}{Z} M_y \mathrm{\hat{y}} \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) - \frac{M_y}{Z} y{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)\Bigg] $$
#
# $$ \mathbf{E} = - \frac{k^2}{4\pi} M_y \Bigg(\frac{z + i z_c}{R} \mathbf{\hat{x}} - \frac{x}{R} \mathbf{\hat{z}} \Bigg)\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg) e^{-ikR} $$

# %% [markdown]
# And add them to the first set of equations
#
# $$ \mathbf{E} = \frac{k^2}{4\pi} Z \Bigg[J_x \mathrm{\hat{x}} \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + \frac{J_x x}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg) $$
#
# $$ - \frac{k^2}{4\pi} M_y \Bigg(\frac{z + i z_c}{R} \mathbf{\hat{x}} - \frac{x}{R} \mathbf{\hat{z}} \Bigg)\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg)\Bigg] e^{-ikR} $$

# %% [markdown]
# $$ \mathbf{H} = \frac{k^2}{4\pi} \Bigg[\frac{1}{Z} M_y \mathrm{\hat{y}} \Bigg( \frac{-i}{kR} - \frac{1}{(kR)^2} + \frac{i}{(kR)^3}\Bigg) + \frac{M_y}{Z} \frac{y}{R^2} \big(x \mathbf{\hat{x}} + y \mathbf{\hat{y}} + (z + i z_c) \mathbf{\hat{z}}\big)\Bigg( \frac{i}{kR} + \frac{3}{(kR)^2} - \frac{3i}{(kR)^3} \Bigg)$$
#
# $$ + \frac{k^2}{4\pi} J_x\Bigg(\frac{z + i z_c}{R} \mathbf{\hat{y}} - \frac{y}{R} \mathbf{\hat{z}} \Bigg)\Bigg(\frac{i}{kR}+\frac{1}{(kR)^2}\Bigg)\Bigg]  e^{-ikR} $$

# %% [markdown]
# These fields will be invariant if $M_y$ = $-Z J_x$.

# %% [markdown]
# # Symmetrized Gaussian beam in GRASP normalization
#
# Our forward time direction fields for a symmetrized Gaussian beam are therefore:
#
# $$ E_x = \frac{Z J_x k^2}{4 \pi} e^{-ikr}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = - \frac{Z J_x k^2}{4 \pi} e^{-ikr}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = - \frac{Z J_x k^2}{4 \pi} e^{-ikr}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = -\frac{Z J_x k^2}{4 \pi } e^{-ikr}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = \frac{Z J_x k^2}{4 \pi } e^{-ikr}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{y^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = - \frac{Z J_x k^2}{4 \pi } e^{-ikr}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# # Normalization
#
# The above equations give results with very large or small magnitudes for the fields due to the imaginary part of $r$ giving the exponential of a real number in $e^{±i k r}$. We also would like the phase of the E-field to be zero at the origin.  Per Cullen & Yu, we therefore multiply the fields by a constant factor $ - e^{\mp k z_c} $, so that:
#
# $$ e^{-i k r} \rightarrow e^{- i k r - k z_c} $$
#
# We wish to normalize the power in the beam to $4\pi \sqrt{\mathrm{Watt}}$.  To do so, we must multiply the beam by a normalizing factor
#
#
#
# $$ \frac{- 4 \pi z_c}{2 Z k w_0} e^{- kz_c} =  $$

# %% [markdown]
# $$ z_c = \pi w_0^2 / \lambda = k w_0^2 / 2 $$

# %% [markdown]
# $$ \frac{4 \pi w_0}{\sqrt{2} Z} e^{- k^2 w_0^2 / 2}$$

# %% [markdown]
# # Final form
#
# The final form for the fields of a Gaussian beam, normalized to $4 \pi \sqrt{\mathrm{W}}$ are:

# %% [markdown]
# $$ E_x = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ E_y = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ E_z = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{x}{r}\Bigg] $$
#
# $$ H_x = -\frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$
#
# $$ H_y = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2} e^{ikr}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{y^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$
#
# $$ H_z = - \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2} e^{ikr}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{y}{r}\Bigg] $$

# %% [markdown]
# # Implementation
#
# We now implement each of these fields in numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy as sp
    
from PyPO.System import System
from PyPO.Enums import Units

# %% [markdown]
# ## Define the Gaussian Beam

# %%
# Setting up parameters for defining simulation.
# Source parameters and distances
lam = 10*Units.MM                # Wavelength of light in mm
k = 2*np.pi/lam
print(f"Wavenumber                : {k:7.3f} mm")

w0 = 5*lam  # Gaussian beamwaist

r_source = 2.5*w0               # Radius of disk in mm
print(f"Radius of source grid     : {r_source:7.3f} mm")

zc = np.pi*w0**2 / lam # Confocal distance in mm
print(f"Confocal distance         : {zc:7.3g} mm")

E0 = np.sqrt(8/(w0**2)) # Normalise to 4pi Watts
print(f"Field normalization       : {E0:7.3g} √Watt")

theta_0 = np.rad2deg(np.atan(lam/(np.pi*w0))) # Calculate far-field divergence angle
print(f"Farfield divergence angle : {theta_0:7.3f}°")

fwhm = 1.18*theta_0
print(f"Farfield FWHM angle       : {fwhm:7.3f}°")

# Calculate the size at the test point
z_grid = 100*lam
print(f"Near-field grid distance     : {z_grid:7.3f} mm")

w_grid = w0*np.sqrt(1 + ((lam*z_grid)/(np.pi*w0**2))**2)
print(f"Beamwidth at near-field grid : {w_grid:7.3f} mm")
# Out:
# Wavenumber                :   0.628 mm
# Radius of source grid     : 125.000 mm
# Confocal distance         :     785 mm
# Field normalization       :  0.0566 √Watt
# Farfield divergence angle :   3.643°
# Farfield FWHM angle       :   4.298°
# Near-field grid distance     : 1000.000 mm
# Beamwidth at near-field grid :  80.950 mm

# %%
# Create a system

s = System()
# Out:
# 2026-03-10 16:02:02 - WARNING - System override set to True.

# %%
# Create a source grid
source_plane = {
        "name"      : "source_plane",
        "gmode"     : "uv",
        # "lims_x"    : np.array([-r_disk, r_disk]),
        # "lims_y"    : np.array([-r_disk, r_disk]),
        "lims_u"    : np.array([0, r_source]),
        "lims_v"    : np.array([0, 360]),
        "gridsize"  : np.array([101, 360])
        }

s.addPlane(source_plane)

s.translateGrids("source_plane", np.array((0, 0, z_grid)))

source_grid = s.generateGrids("source_plane")
# Out:
# 2026-03-10 16:02:03 - INFO - Added plane source_plane to system.
# 2026-03-10 16:02:03 - INFO - Translated element source_plane by ('0.000e+00', '0.000e+00', '1.000e+03') millimeters.

# %% [markdown]
# ## Electric field

# %%
# Precalculate r

r = np.sqrt(source_grid.x**2 + source_grid.y**2 + (source_grid.z + 1j*zc)**2)

# %%
r
# Out:
# array([[1000.        +785.3981634j , 1000.        +785.3981634j ,
#         1000.        +785.3981634j , ..., 1000.        +785.3981634j ,
#         1000.        +785.3981634j , 1000.        +785.3981634j ],
#        [1000.00048319+785.3977839j , 1000.00048319+785.3977839j ,
#         1000.00048319+785.3977839j , ..., 1000.00048319+785.3977839j ,
#         1000.00048319+785.3977839j , 1000.00048319+785.3977839j ],
#        [1000.00193277+785.39664541j, 1000.00193277+785.39664541j,
#         1000.00193277+785.39664541j, ..., 1000.00193277+785.39664541j,
#         1000.00193277+785.39664541j, 1000.00193277+785.39664541j],
#        ...,
#        [1004.64618309+781.76593573j, 1004.64618309+781.76593573j,
#         1004.64618309+781.76593573j, ..., 1004.64618309+781.76593573j,
#         1004.64618309+781.76593573j, 1004.64618309+781.76593573j],
#        [1004.74160286+781.69169184j, 1004.74160286+781.69169184j,
#         1004.74160286+781.69169184j, ..., 1004.74160286+781.69169184j,
# ...

# %% [markdown]
# ### $E_x$ component
#
# $$ E_x = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$

# %%
prefactor = - w0/np.sqrt(2) * k**2 * np.exp(-1j * k * r - k**2 * w0**2 / 2)

# %%
term1 = - 1j/(k*r) - 1/(k*r)**2 + 1j/(k*r)**3
term2 = (1j/(k*r) + 3/(k*r)**2 - 3j/(k*r)**3) * (source_grid.x**2 / r**2)
term3 = (1j/(k*r) + 1 /(k*r)**2) * (source_grid.z + 1j*zc) / r

# %%
Ex = prefactor * (term1 + term2 - term3)

# %%
efield = Ex

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(efield)))

print(vmax)

vmin = vmax - 40

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 0

xlabel = 'Radius (mm)'

vrange = 40

vmax = 20*np.log10(np.max(np.abs(efield)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
### Check the normalization

P_Ex = sp.integrate.trapezoid(np.sum(np.abs(Ex)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Ex)
# Out:
# 0.9804505536961451

# %% [markdown]
# ### $E_y$ component
#
# $$ E_y = - \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$

# %%
Ey = - prefactor*( 1j / (k*r) + 3/ (k*r)**2 - 3j/(k*r)**3) * source_grid.x * source_grid.y / r**2

# %%
efield = Ey

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(Ex)))

print(vmax)

vmin = vmax - 80

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax, vmax=vmax, vmin=vmin)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 45

xlabel = 'Radius (mm)'

vrange = 100

vmax = 20*np.log10(np.max(np.abs(Ex)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ex[:,row])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
# Check sum
P_Ey = sp.integrate.trapezoid(np.sum(np.abs(Ey)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Ey)
# Out:
# 2.16523990691595e-07

# %% [markdown]
# ### $E_z$ component
#
# $$ E_z = - \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{x}{r}\Bigg] $$

# %%
term1 = (1j/(k*r) + 3/(k*r)**2 - 3j/(k*r)**3) * source_grid.x * (source_grid.z + 1j*zc) / r**2

# %%
term2 = ( 1j/(k*r)**2 + 1/(k*r)**3) * source_grid.x / r

# %%
Ez = -prefactor*(term1 - term2)

# %%
efield = Ez

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(Ex)))

print(vmax)

vmin = vmax - 120

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax, vmax=vmax, vmin=vmin)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 0
row_d = 45

xlabel = 'Radius (mm)'

vrange = 80

vmax = 20*np.log10(np.max(np.abs(Ex)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ex[:,row])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ey[:,row_d])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
P_Ez = sp.integrate.trapezoid(np.sum(np.abs(Ez)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Ez)
# Out:
# 0.0002371023721733008

# %%
print(P_Ex + P_Ey + P_Ez)
# Out:
# 0.9806878725923092

# %% [markdown]
# ## Magnetic Field

# %% [markdown]
# ### $H_x$ component

# %% [markdown]
# $$ H_x = -\frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2}\bigg(\frac{i}{(k r)} + \frac{3}{(kr)^2} - \frac{3i}{(kr)^2}\bigg)\frac{xy}{r^2} $$

# %%
Hx = - prefactor*( 1j / (k*r) + 3/ (k*r)**2 - 3j/(k*r)**3) * source_grid.x * source_grid.y / r**2

# %%
efield = Hx

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(Ex)))

print(vmax)

vmin = vmax - 80

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax, vmax=vmax, vmin=vmin)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 45

xlabel = 'Radius (mm)'

vrange = 100

vmax = 20*np.log10(np.max(np.abs(Ex)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ex[:,row])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
# Check sum
P_Hx = sp.integrate.trapezoid(np.sum(np.abs(Hx)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Hx)
# Out:
# 2.16523990691595e-07

# %% [markdown]
# ### $H_y$ component
#
# $$ H_y = \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2} e^{ikr}\Bigg[\bigg(\frac{-i}{(kr)} - \frac{1}{(kr)^2} + \frac{i}{(kr)^3}\bigg) + \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{y^2}{r^2} - \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{z + i z_c}{r}\Bigg] $$

# %%
term1 = - 1j/(k*r) - 1/(k*r)**2 + 1j/(k*r)**3
term2 = (1j/(k*r) + 3/(k*r)**2 - 3j/(k*r)**3) * (source_grid.y**2 / r**2)
term3 = (1j/(k*r) + 1 /(k*r)**2) * (source_grid.z + 1j*zc) / r

# %%
Hy = prefactor * (term1 + term2 - term3)

# %%
efield = Hy

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(efield)))

print(vmax)

vmin = vmax - 40

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 0

xlabel = 'Radius (mm)'

vrange = 40

vmax = 20*np.log10(np.max(np.abs(efield)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
### Check the normalization

P_Hy = sp.integrate.trapezoid(np.sum(np.abs(Hy)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Hy)
# Out:
# 0.9804505536961451

# %% [markdown]
# ### $H_z$ component
#
# $$ H_z = - \frac{w_0 k^2}{\sqrt{2}} e^{-ikr - k^2w_0^2/2} e^{ikr}\Bigg[ \bigg(\frac{i}{(k r)} + \frac{3i}{(kr)^2} - \frac{3}{(kr)^3}\bigg)\frac{x(z + i z_c)}{r^2} + \bigg(\frac{i}{(kr)} + \frac{1}{(kr)^2}\bigg)\frac{y}{r}\Bigg] $$

# %%
term1 = (1j/(k*r) + 3/(k*r)**2 - 3j/(k*r)**3) * source_grid.x * (source_grid.z + 1j*zc) / r**2

# %%
term2 = ( 1j/(k*r)**2 + 1/(k*r)**3) * source_grid.x / r

# %%
Hz = - prefactor*(term1 + term2)

# %%
efield = Hz

grid = source_grid

vmax = 20*np.log10(np.max(np.abs(Ex)))

print(vmax)

vmin = vmax - 120

x_grid = grid.x
y_grid = grid.y
z_grid = grid.z
phase_factor = np.exp(1j*2*np.pi/lam*z_grid)
#phase_factor = 1
fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})

ampfig = ax[0].pcolormesh(x_grid, y_grid, 20*np.log10(np.abs(efield)) - vmax, vmax=vmax, vmin=vmin)
phasefig = ax[1].pcolormesh(x_grid, y_grid, np.angle(efield))

c1 = fig.colorbar(ampfig, orientation='vertical')
c2 = fig.colorbar(phasefig, orientation='vertical')

ax[0].set_aspect(1)
ax[1].set_aspect(1)
# Out:
# -29.140115772108842

# %%
row = 0
row_d = 45

xlabel = 'Radius (mm)'

vrange = 80

vmax = 20*np.log10(np.max(np.abs(Ex)))
print(vmax)
vmin = vmax - vrange

fig, ax = plt.subplots(1,2, figsize=(10,5), gridspec_kw={'wspace':0.5})
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ex[:,row])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(Ey[:,row_d])))
ax[0].plot(grid.x[:,row], 20*np.log10(np.abs(efield[:,row])))
ax[0].axvline(w_grid, ls=":")
ax[0].axhline(vmax+20*np.log10(np.exp(-1)), ls=":")
ax[0].set_ylim((vmin, vmax+1))
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('Scalar field power (dBi)')

ax[1].plot(grid.x[:,row], np.unwrap(np.angle(efield[:,row])))
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Scalar field Phase (rad)')
# Out:
# -29.140115772108842
# Text(0, 0.5, 'Scalar field Phase (rad)')

# %%
P_Hz = sp.integrate.trapezoid(np.sum(np.abs(Hz)**2 * (r_source/101) * np.sqrt(grid.x**2 + grid.y**2) * np.deg2rad(1), axis=1)) / (4*np.pi)
print(P_Hz)
# Out:
# 0.00023804067899132716

# %%
print(P_Hx + P_Hy + P_Hz)
print(P_Ex + P_Ey + P_Ez)
# Out:
# 0.9806888108991272
# 0.9806878725923092

# %% [markdown]
# # Source currents
#
# We now calculate the source current distribution on a (real) plane that will give rise to these fields.

# %% [markdown]
# We want the radiated fields at the plane to be equal to the incident fields.  The induced currents on a surface that give rise to a radiated fields that is equal to the incident fields are those of a perfect electrical conductor for the electric current elements, and those of a perfect magnetic conductor for the magnetic current elements.  In each case, the respective equivalent currents are:
#
# $$ \mathbf{J} = 2 \mathbf{n} \times \mathbf{H} $$
#
# $$ \mathbf{M} = -2 \mathbf{n} \times \mathbf{E} $$

# %% [markdown]
# For a plane surface normal to the z-axis, this becomes:
#
# $$ \mathbf{J} = -2 H_y \mathbf{\hat{x}} + 2 H_x \mathbf{\hat{y}} $$
#
# $$ \mathbf{M} = 2 E_y \mathbf{\hat{x}} - 2 E_x \mathbf{\hat{y}} $$
